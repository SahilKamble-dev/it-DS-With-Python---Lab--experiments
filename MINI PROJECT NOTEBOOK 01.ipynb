# %% [markdown]
# <a href="https://colab.research.google.com/github/SahilKamble-dev/it-DS-With-Python---Lab--experiments/blob/main/MINI%20PROJECT%20NOTEBOOK%2001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project: Weather Prediction Dataset**

# %% [markdown]
# **Dataset Selection**

# %% [markdown]
# The dataset used in this project is a Weather Prediction dataset. It contains weather-related attributes such as temperature, humidity, pressure, cloud cover, and precipitation for different cities. The dataset is used to analyze weather patterns and prepare it for machine learning models.

# %% [markdown]
#  1. Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2. Upload Dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-48ba59be-7b43-4ca3-a32c-feea0e94398c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48ba59be-7b43-4ca3-a32c-feea0e94398c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 3 :- Then Load Dataset

# %%
import pandas as pd

df = pd.read_csv("weather_prediction_dataset_light.csv")
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
# 4                    0.51                 0.07             3.7
#
#    BASEL_temp_mean  BASEL_temp_min  ...  SONNBLICK_temp_mean  \
# 0              2.9             1.6  ...                -15.2
# ...

# %% [markdown]
# 4 :- Understanding the Data

# %%
df.shape
# Out:
# (3654, 91)

# %%
df.columns
# Out:
# Index(['DATE', 'MONTH', 'BASEL_cloud_cover', 'BASEL_humidity',
#        'BASEL_pressure', 'BASEL_global_radiation', 'BASEL_precipitation',
#        'BASEL_sunshine', 'BASEL_temp_mean', 'BASEL_temp_min', 'BASEL_temp_max',
#        'DE_BILT_cloud_cover', 'DE_BILT_humidity', 'DE_BILT_pressure',
#        'DE_BILT_global_radiation', 'DE_BILT_precipitation', 'DE_BILT_sunshine',
#        'DE_BILT_temp_mean', 'DE_BILT_temp_min', 'DE_BILT_temp_max',
#        'DRESDEN_cloud_cover', 'DRESDEN_humidity', 'DRESDEN_global_radiation',
#        'DRESDEN_precipitation', 'DRESDEN_sunshine', 'DRESDEN_temp_mean',
#        'DRESDEN_temp_min', 'DRESDEN_temp_max', 'DUSSELDORF_cloud_cover',
#        'DUSSELDORF_humidity', 'DUSSELDORF_pressure',
#        'DUSSELDORF_global_radiation', 'DUSSELDORF_precipitation',
#        'DUSSELDORF_sunshine', 'DUSSELDORF_temp_mean', 'DUSSELDORF_temp_min',
#        'DUSSELDORF_temp_max', 'HEATHROW_cloud_cover', 'HEATHROW_humidity',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3654 entries, 0 to 3653
# Data columns (total 91 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DATE                         3654 non-null   int64
#  1   MONTH                        3654 non-null   int64
#  2   BASEL_cloud_cover            3654 non-null   int64
#  3   BASEL_humidity               3654 non-null   float64
#  4   BASEL_pressure               3654 non-null   float64
#  5   BASEL_global_radiation       3654 non-null   float64
#  6   BASEL_precipitation          3654 non-null   float64
#  7   BASEL_sunshine               3654 non-null   float64
#  8   BASEL_temp_mean              3654 non-null   float64
#  9   BASEL_temp_min               3654 non-null   float64
#  10  BASEL_temp_max               3654 non-null   float64
#  11  DE_BILT_cloud_cover          3654 non-null   int64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                  8            0.89          1.0286
# 1     20000102      1                  8            0.87          1.0318
# 2     20000103      1                  5            0.81          1.0314
# 3     20000104      1                  7            0.79          1.0262
# 4     20000105      1                  5            0.90          1.0246
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                  7            0.82          1.0084
# 3650  20091229     12                  7            0.92          1.0028
# 3651  20091230     12                  8            0.92          0.9979
# 3652  20091231     12                  7            0.93          0.9958
# 3653  20100101      1                  8            0.93          0.9965
#
# ...

# %% [markdown]
# Explanation
#
# Dataset contains weather-related features like temperature, humidity, wind, etc.
# Target variable is the last column (prediction output).

# %% [markdown]
# 5. Check Missing Values

# %%
df.isnull().sum()
# Out:
# DATE                      0
# MONTH                     0
# BASEL_cloud_cover         0
# BASEL_humidity            0
# BASEL_pressure            0
#                          ..
# TOURS_global_radiation    0
# TOURS_precipitation       0
# TOURS_temp_mean           0
# TOURS_temp_min            0
# TOURS_temp_max            0
# Length: 91, dtype: int64

# %% [markdown]
# After checking missing values using df.isnull().sum(), it was observed that all columns contain 0 missing values. Hence, no data cleaning was required for missing values.

# %% [markdown]
# 6. Check Duplicate Data

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col])

df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
# 4                    0.51                 0.07             3.7
#
#    BASEL_temp_mean  BASEL_temp_min  ...  SONNBLICK_temp_mean  \
# 0              2.9             1.6  ...                -15.2
# ...

# %% [markdown]
# 7. Convert Categorical Data to Numeric

# %% [markdown]
#  Final Conclusion

# %% [markdown]
# The dataset was successfully cleaned and preprocessed. It contains no missing or duplicate values, and all necessary transformations were applied. The dataset is now ready for model building and prediction.
