# %% [markdown]
# <a href="https://colab.research.google.com/github/SahilKamble-dev/it-DS-With-Python---Lab--experiments/blob/main/EXPERIMENT_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Experiment No : 03

# %% [markdown]
# Aim :
#
# Learn basics of maplotlib library and its use as visualisation tool in data science pipeline and learn about line plots and scatter plots.

# %% [markdown]
# Theory :
#
# Matplotlib is a multi-platform data visualization library built on NumPy arrays, and designed to work with the broader SciPy stack.
#
# It was conceived by John Hunter in 2002, originally as a patch to IPython for enabling interactive MATLAB-style plotting via gnuplot from the IPython command line.
#
# One of Matplotlib’s most important features is its ability to play well with many operating systems and graphics backends. Matplotlib supports dozens of backends and output types, which means you can count on it to work regardless of which operating system you are using or which output format you wish.
#
# This cross-platform, everything-to-everyone approach has been one of the great strengths of Matplotlib. It has led to a large user base, which in turn has led to an active developer base and Matplotlib’s powerful tools and ubiquity within the scientific Python world.
#
# In recent years, however, the interface and style of Matplotlib have begun to show their age. Newer tools like ggplot and ggvis in the R language, along with web visualization toolkits based on D3js and HTML5 canvas, often make Matplotlib feel clunky and old-fashioned.

# %% [markdown]
# Performance :
#
# [Students need to execute eaxh and every cell in this section and note the output of the same. Once done they have to answer Questions mentioned in review section]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.__version__
# Out:
# '3.10.0'

# %%
# %matplotlib inline
import numpy as np
x = np.linspace(0, 10, 1000)

fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# Saving Figures to File
#
# One nice feature of Matplotlib is the ability to save figures in a wide variety of formats. Saving a figure can be done using the savefig() command. For example, to save the previous figure as a PNG file, you can run this:

# %%
fig.savefig('my_figure.png')

# %%
from IPython.display import Image
Image('my_figure.png')

# %%
{'eps': 'Encapsulated Postscript',
 'jpeg': 'Joint Photographic Experts Group',
 'jpg': 'Joint Photographic Experts Group',
 'pdf': 'Portable Document Format',
 'pgf': 'PGF code for LaTeX',
 'png': 'Portable Network Graphics',
 'ps': 'Postscript',
 'raw': 'Raw RGBA bitmap',
 'rgba': 'Raw RGBA bitmap',
 'svg': 'Scalable Vector Graphics',
 'svgz': 'Scalable Vector Graphics',
 'tif': 'Tagged Image File Format',
 'tiff': 'Tagged Image File Format'}
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpeg': 'Joint Photographic Experts Group',
#  'jpg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# Matplotlib API Interfaces
#
# A potentially confusing feature of Matplotlib is its dual interfaces: a convenient MATLAB-style state-based interface, and a more powerful object-oriented interface. This section we will review them breifly.
# MATLAB-style Interface
#
# Matplotlib was originally written as a Python alternative for MATLAB users, and much of its syntax reflects that fact. The MATLAB-style tools are contained in the pyplot (plt) interface. See the example inthe code cell below.

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# This interface is stateful: It keeps track of the "current" figure and axes, which are where all plt commands are applied.
#
# You can get a reference to these using the plt.gcf() (get current figure) and plt.gca() (get current axes) routines.
#
# While this stateful interface is fast and convenient for simple plots, it is easy to run into problems.
#
# For example, once the second panel is created, how can we go back and add something to the first? This interface does have a solution but it is not a easy solution.

# %% [markdown]
# Object-oriented interface of Matplotlib
#
# The object-oriented interface can nicely handle more complicated plots, and for when you want more control over your figure.
#
# Rather than depending on some notion of an "active" figure or axes, in the object-oriented interface the plotting functions are methods of explicit Figure and Axes objects.
#
# To re-create the previous plot using this style of plotting, you might do the following:

# %%
#First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# he difference is as small as switching plt.plot() to ax.plot().
#
# Now we start exploring different types of plots in following sections.

# %% [markdown]
# In Matplotlib, the figure (an instance of the class plt.Figure) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels.
#
# The axes (an instance of the class plt.Axes) is what we see above: a bounding box with ticks and labels, which will eventually contain the plot elements that make up our visualization.
#
# Once we have created an axes, we can use the ax.plot function to plot some data.

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %% [markdown]
# The word line in line plot refers to the function we want to plot. Multiple functions can be plot on same plot like shown below.

# %%
plt.plot(x, np.sin(x))   #shown in blue
plt.plot(x, np.sin(2*x)) #Shown in green
plt.plot(x,(x**(1/2))/2) #Shown in red

# %% [markdown]
# Adjusting the Plot: Line Colors and Styles
#
# The first adjustment you might wish to make to a plot is to control the line colors and styles. The plt.plot() function takes additional arguments that can be used to specify these. To adjust the color, you can use the color keyword, which accepts a string argument representing virtually any imaginable color. The color can be specified in a variety of ways:

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# Adjusting the Plot: Axes Limits
#
# Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control. The most basic way to adjust axis limits is to use the plt.xlim() and plt.ylim() methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# Labeling Plots
#
# As the last piece of this section, we'll briefly look at the labeling of plots: titles, axis labels, and simple legends.
#
# Titles and axis labels are the simplest such labels—there are methods that can be used to quickly set them:

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# Simple Scatter Plots
#
# Another commonly used plot type is the simple scatter plot, a close cousin of the line plot. Instead of points being joined by line segments, here the points are represented individually with a dot, circle, or other shape.

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %% [markdown]
# Scatter Plots with plt.scatter
#
# A second, more powerful method of creating scatter plots is the plt.scatter function, which can be used very similarly to the plt.plot function:

# %%
# Consider this code for scatter plot

rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %% [markdown]
# **Question Answer Section**

# %% [markdown]
# 1:-List any 2 python APIs that are used for Plotting Graphs.

# %% [markdown]
# Ans Matplotlib
#
# Matplotlib is an open-source Python library for creating static, animated, and interactive visualizations. It provides a comprehensive environment for producing publication-quality plots across platforms and is foundational to the Python scientific and data-analysis ecosystem.
# Key facts
#
#     Created by: John D. Hunter (2003)
#
#     Maintained by: Matplotlib community under NumFOCUS
#
#     Programming language: Python
#
#     License: BSD-compatible (based on Python Software Foundation license)
#
#     Latest stable version: 3.10+ (2025)

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# Seaborn
#
# Seaborn is an open-source Python library for creating statistical data visualizations. Built on top of Matplotlib and tightly integrated with Pandas, it simplifies the creation of complex, publication-quality graphics for exploratory data analysis and presentation. It is widely used across data science, analytics, and academic research for its ease of use and aesthetically pleasing defaults.
# Key facts
#
#     Initial release: 2012
#
#     Developer: Michael Waskom and community contributors
#
#     License: BSD (open source)
#
#     Latest stable version: 0.13.2 (2024)
#
#     Dependencies: Matplotlib, Pandas, NumPy
#
# Features and Capabilities
#
# Seaborn provides a high-level API for statistical plotting that handles data directly from Pandas DataFrames. It offers specialized functions for relational, categorical, and distribution plots—such as scatter, box, violin, bar, and heatmap visualizations—while automatically computing statistical aggregates and confidence intervals. Built-in themes, color palettes, and context settings help produce polished visuals with minimal customization.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.barplot(x="day", y="total_bill", data=tips)

plt.title("Bar Graph using Seaborn")
plt.show()

# %% [markdown]
# 2:- Name 2 important machnisms used for accesssing Matplotlib API.

# %% [markdown]
# Ans :- 1. Pyplot Interface
#
# It provides a MATLAB-like interface for plotting.
#
# It is simple and commonly used for basic graphs.
#
# Example:

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,30,40]

plt.plot(x,y)
plt.title("Line Graph")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()

# %% [markdown]
# 2. Object-Oriented Interface
#
# It gives more control over figures and axes.
#
# Mostly used for complex and customized plots.
#
# Example:

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

x = [1,2,3,4]
y = [10,20,30,40]

ax.plot(x,y)
ax.set_title("Line Graph")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")

plt.show()

# %% [markdown]
# 3 :- Create a collection of 100 random normal numbers with parameter mean 30, sd 4 store it in object summer_temp

# %%
import numpy as np

summer_temp = np.random.normal(loc=30, scale=4, size=100)

print(summer_temp)
# Out:
# [40.85612516 29.47498245 27.03515396 23.76475417 26.96060877 34.38666262
#  28.99463167 27.80271416 27.0476205  31.38397359 29.64104907 29.42858723
#  27.56310734 32.12569727 30.55594814 33.39392249 25.61680711 30.96047992
#  27.75806101 25.50195818 39.8453772  26.11159247 35.60357488 31.2781696
#  28.84272554 35.71150012 33.50831608 21.43684983 39.24473012 34.88028313
#  32.00304146 26.13499022 30.9079752  29.33136992 36.83621968 27.87576857
#  31.29999015 30.13002206 24.5737399  29.282003   30.85574212 25.08968797
#  29.13506515 34.72356348 27.98331109 30.04197901 26.84218477 34.3353516
#  30.12440019 29.9707891  25.21663801 34.9578296  30.9202115  20.43867854
#  30.30782091 32.59151248 33.52372606 25.11898331 30.40114095 29.18835179
#  29.39516866 31.39152042 25.66985277 26.7452755  30.08388202 31.43825752
#  36.54869233 21.34493114 27.98804799 28.95620491 33.78603722 37.68490601
#  24.66761452 26.445808   37.32210244 24.83377683 35.65317912 34.33537468
# ...

# %% [markdown]
# Explanation:
#
# loc = 30 → mean
#
# scale = 4 → standard deviation
#
# size = 100 → number of random values
#
# summer_temp → object storing the generated numbers.

# %% [markdown]
#  4:- sort above set and store in objrct sorted_summer_temp

# %% [markdown]
# Ans :- You can sort the previous set using NumPy and store it in sorted_summer_temp.

# %%
import numpy as np

summer_temp = np.random.normal(loc=30, scale=4, size=100)

sorted_summer_temp = np.sort(summer_temp)

print(sorted_summer_temp)
# Out:
# [18.52675071 18.73473553 19.88365426 22.94045822 23.04213979 23.20610315
#  23.49733643 23.64549349 24.20974839 24.74263325 24.88025618 24.88349349
#  25.20595726 25.25414403 25.55225772 25.57286686 25.64068327 25.79393826
#  26.10019464 26.11068593 26.32879556 26.45420587 26.51609427 26.91716147
#  27.00493371 27.01691823 27.05536242 27.06558749 27.20264054 27.34159277
#  27.43829393 27.50104845 27.54165415 27.56288732 27.82515514 27.82939207
#  28.16562335 28.2206374  28.25141696 28.30796233 28.36484961 28.37382993
#  28.49033554 28.7722259  28.86539306 28.90610386 28.95253077 29.00954335
#  29.13272695 29.22257761 29.38267489 29.70896811 29.99921552 30.01392298
#  30.06002177 30.21416961 30.27602548 30.29565799 30.34569567 30.49507048
#  30.53869668 31.12551135 31.34598788 31.46004305 31.50969661 31.65418746
#  31.77791388 31.8081935  31.92322477 31.93260632 31.97945342 32.04135738
#  32.16115769 32.20354678 32.23189909 32.32782182 32.49180708 32.5649882
# ...

# %% [markdown]
# Explanation:
#
# np.sort() sorts the numbers in ascending order.
#
# The sorted values are stored in sorted_summer_temp.

# %% [markdown]
# 4 :- Store average of 25 consecutive elements from sorted_summer_temp into object x and plot it as a line plot. What kind of information do u get about the data?

# %%
import numpy as np
import matplotlib.pyplot as plt

# generate and sort data
summer_temp = np.random.normal(loc=30, scale=4, size=100)
sorted_summer_temp = np.sort(summer_temp)

# average of 25 consecutive elements
x = [np.mean(sorted_summer_temp[i:i+25]) for i in range(0, 100, 25)]

# line plot
plt.plot(x, marker='o')
plt.title("Average of 25 Consecutive Values")
plt.xlabel("Group")
plt.ylabel("Average Temperature")
plt.show()

# %% [markdown]
# Information obtained from the plot
#
# The line plot shows the average of each group of 25 values.
#
# Since the data comes from a normal distribution, the averages will gradually increase because the data was sorted.
#
# It helps to observe the trend and spread of the data.
#
# You can see how the temperature values change from lower to higher ranges across the dataset.

# %% [markdown]
# 5 :- Sort above set and store in objrct sorted_summer_temp

# %%
import numpy as np

# assume summer_temp already contains 100 random values
sorted_summer_temp = np.sort(summer_temp)

print(sorted_summer_temp)
# Out:
# [22.05301913 23.41122548 24.19987906 24.23684492 24.47575486 24.49676399
#  24.62695581 24.86031845 24.8679329  24.87069662 24.97754501 25.01388645
#  25.74102809 25.97339535 26.05816221 26.12439139 26.1563186  26.1907567
#  26.23138326 26.52963068 26.5978103  26.95194438 27.02941248 27.07849068
#  27.09478801 27.10024493 27.41540404 27.71325948 27.78713278 27.88930225
#  27.92904666 27.97365541 28.44561416 28.47204897 28.51054425 28.74670636
#  28.85895882 28.90592083 28.95862863 29.06593402 29.13751103 29.13904168
#  29.25569184 29.62940758 29.73605753 29.78417998 29.82253866 29.87021595
#  29.90721892 29.91866473 29.97685493 30.00161955 30.31032388 30.35544071
#  30.37948325 30.41388117 30.556502   30.62283304 30.6577293  30.68587709
#  30.73643535 30.95720523 31.04925038 31.12507086 31.33459431 31.34259109
#  31.39830172 31.57398374 31.65845817 31.76963545 31.78124864 31.88474316
#  31.93083349 32.23981608 32.25154376 32.25547547 32.54767966 32.91673928
# ...

# %% [markdown]
# Explanation:
#
# np.sort() sorts the values in ascending order.
#
# The sorted values are stored in the object sorted_summer_temp.

# %% [markdown]
# 6:- Repeat above step for summer_temp, store summary in object y and this time use scatter plot to plot values. What kind of information do u get about the data?

# %%
import numpy as np
import matplotlib.pyplot as plt

# assume summer_temp already exists
# average of 25 consecutive elements (without sorting)
y = [np.mean(summer_temp[i:i+25]) for i in range(0,100,25)]

# scatter plot
plt.scatter(range(len(y)), y)
plt.title("Average of 25 Consecutive Values")
plt.xlabel("Group")
plt.ylabel("Average Temperature")
plt.show()

# %% [markdown]
# Information obtained from the scatter plot
#
# The plot shows the average values of each group of 25 temperatures.
#
# Since the data is not sorted, the points appear randomly scattered.
#
# It helps to observe variation and randomness in the dataset.
#
# You can see whether any group has unusually high or low average values.
#
#
#
#
# Seaborn
# Seaborn
#
# Seaborn is an open-source Python library for creating statistical data visualizations. Built on top of Matplotlib and tightly integrated with Pandas, it simplifies the creation of complex, publication-quality graphics for exploratory data analysis and presentation. It is widely used across data science, analytics, and academic research for its ease of use and aesthetically pleasing defaults.
#
# Key facts
#
# Initial release: 2012
#
# Developer: Michael Waskom and community contributors
#
# License: BSD (open source)
#
# Latest stable version: 0.13.2 (2024)
#
# Dependencies: Matplotlib, Pandas, NumPy
#
# Features and Capabilities
#
# Seaborn provides a high-level API for statistical

# %% [markdown]
# 7:- plot summer_temp and y together in same line plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

# generate data
summer_temp = np.random.normal(30, 4, 100)

# average of 25 consecutive elements
y = [np.mean(summer_temp[i:i+25]) for i in range(0,100,25)]

# line plot of summer_temp
plt.plot(summer_temp, label="summer_temp")

# line plot of y
plt.plot(range(0,100,25), y, marker='o', label="y (avg of 25 values)")

plt.title("Summer Temperature and Group Averages")
plt.xlabel("Index")
plt.ylabel("Temperature")
plt.legend()

plt.show()

# %% [markdown]
# What the plot shows
# summer_temp line shows the variation of all 100 temperature values.
#
# y line shows the average temperature of each group of 25 values.
#
# It helps compare individual data fluctuations vs overall group trends.

# %% [markdown]
# **Conclusion**
#
# Thus we have learned abou basics of ploting using matplotlib.
